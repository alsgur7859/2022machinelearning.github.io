# %% [markdown]
# # Logistic Regression with non-linear features

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import ticker, cm

# %% [markdown]
# ## load training data

# %%
fname_data1 = 'assignment_09_data1.txt'
fname_data2 = 'assignment_09_data2.txt'

data1        = np.genfromtxt(fname_data1, delimiter=',')
data2        = np.genfromtxt(fname_data2, delimiter=',')

number_data1 = data1.shape[0]
number_data2 = data2.shape[0]

data1_point     = data1[:, 0:2]
data1_point_x   = data1_point[:, 0]
data1_point_y   = data1_point[:, 1]
data1_label     = data1[:, 2]

data2_point     = data2[:, 0:2]
data2_point_x   = data2_point[:, 0]
data2_point_y   = data2_point[:, 1]
data2_label     = data2[:, 2]

data1_label_class_0     = (data1_label == 0)
data1_label_class_1     = (data1_label == 1)

data2_label_class_0     = (data2_label == 0)
data2_label_class_1     = (data2_label == 1)

data1_point_x_class_0   = data1_point_x[data1_label_class_0]
data1_point_y_class_0   = data1_point_y[data1_label_class_0]

data1_point_x_class_1   = data1_point_x[data1_label_class_1]
data1_point_y_class_1   = data1_point_y[data1_label_class_1]

data2_point_x_class_0   = data2_point_x[data2_label_class_0]
data2_point_y_class_0   = data2_point_y[data2_label_class_0]

data2_point_x_class_1   = data2_point_x[data2_label_class_1]
data2_point_y_class_1   = data2_point_y[data2_label_class_1]

print('shape of point in data1 = ', data1_point.shape)
print('shape of point in data2 = ', data2_point.shape)

print('shape of label in data1 = ', data1_label.shape)
print('shape of label in data2 = ', data2_label.shape)

print('data type of point x in data1 = ', data1_point_x.dtype)
print('data type of point y in data1 = ', data1_point_y.dtype)

print('data type of point x in data2 = ', data2_point_x.dtype)
print('data type of point y in data2 = ', data2_point_y.dtype)
# Out:
# shape of point in data1 =  (1000, 2)
# shape of point in data2 =  (1000, 2)
# shape of label in data1 =  (1000,)
# shape of label in data2 =  (1000,)
# data type of point x in data1 =  float64
# data type of point y in data1 =  float64
# data type of point x in data2 =  float64
# data type of point y in data2 =  float64

# %% [markdown]
# ## plot the data

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in data1')
plt.plot(data1_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data1_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %%
f = plt.figure(figsize=(8,8))   

plt.title('points in data2')
plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
plt.axis('equal')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## define the feature functions

# %% [markdown]
# - feature vector is defined by $(1, f_1(x, y), f_2(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_feature1(point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    #
    feature = np.ones((5,point.shape[0]))
    feature[1] = np.transpose(point)[0]
    feature[2] = np.transpose(point)[1]**2
    feature[3] = np.transpose(point)[0]**2
    feature[4] = np.transpose(point)[0] + np.transpose(point)[1]
    feature = np.transpose(feature)
    
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return feature

# %%
def compute_feature2(point):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks

    feature = np.ones((7,point.shape[0]))
    feature[1] = np.transpose(point)[0]
    feature[2] = np.transpose(point)[0]**2
    feature[3] = np.transpose(point)[0]**3
    feature[4] = np.transpose(point)[0]**4
    feature[5] = np.transpose(point)[1]
    feature[6] = np.transpose(point)[1]**2
    feature = np.transpose(feature)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return feature

# %% [markdown]
# ## define the linear regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature = $(1, f_1(x, y), \cdots, f_{k-1}(x, y)) \in \mathbb{R}^k$

# %%
def compute_linear_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    value = np.inner(np.transpose(theta), feature)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define sigmoid function with input

# %% [markdown]
# - $z \in \mathbb{R}$

# %%
def sigmoid(z):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    value = 1 / (1 + np.exp(-z))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the logistic regression function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$

# %%
def compute_logistic_regression(theta, feature):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    value = sigmoid(compute_linear_regression(theta, feature))
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return value

# %% [markdown]
# ## define the residual function

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_residual(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    
    residual = (label) * (-np.log(compute_logistic_regression(theta, feature))) \
    + (1 - label) * (-np.log(1 - compute_logistic_regression(theta, feature)))

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return residual

# %% [markdown]
# ## define the loss function for the logistic regression

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_loss(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    loss = compute_residual(theta, feature, label).sum() / compute_residual(theta, feature, label).size

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return loss

# %% [markdown]
# ## define the gradient of the loss with respect to the model parameter $\theta$

# %% [markdown]
# - $\theta = (\theta_0, \theta_1, \cdots, \theta_{k-1}) \in \mathbb{R}^k$
# - feature $= (1, f_1(x, y), \cdots, f_{k-1}(x, y) \in \mathbb{R}^k$
# - label $= l \in \{0, 1\}^k$

# %%
def compute_gradient(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    gradient = np.matmul((compute_logistic_regression(theta, feature) - label.reshape(-1,)), feature) / feature.shape[0]

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return gradient

# %% [markdown]
# ## compute the accuracy of the prediction for point with a given model parameter

# %%
def compute_accuracy(theta, feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label_predict = np.logical_not(compute_logistic_regression(theta, feature) < 0.5)
    label_wrong = np.logical_xor(label, label_predict)
    # print(np.logical_xor(label, label_predict))
    accuracy = (label.size - np.count_nonzero(label_wrong)) / label.size
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return accuracy

# %% [markdown]
# ## initialize the gradient descent algorithm

# %%
data1_number_iteration   = 10000
data2_number_iteration   = 20000

data1_learning_rate   = 0.1 
data2_learning_rate   = 0.3

data1_number_feature    = 5
data2_number_feature    = 7 

theta1  = np.zeros(data1_number_feature)
theta2  = np.zeros(data2_number_feature)

data1_loss_iteration  = np.zeros(data1_number_iteration)
data2_loss_iteration  = np.zeros(data2_number_iteration)

data1_accuracy_iteration    = np.zeros(data1_number_iteration)
data2_accuracy_iteration    = np.zeros(data2_number_iteration)

# %% [markdown]
# ## run the gradient descent algorithm to optimize the loss function with respect to the model parameter

# %%
for i in range(data1_number_iteration):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    # print(data1_point)
    # print(compute_feature1(data1_point))
    # print(compute_linear_regression(theta1, compute_feature1(data1_point)))
    # print(compute_logistic_regression(theta1, compute_feature1(data1_point)))
    # print(data1_label)
    # print(compute_gradient(theta1, compute_feature1(data1_point), data1_label))
    # print(theta1 - data1_learning_rate * compute_gradient(theta1, compute_feature1(data1_point), data1_label))
    # print(compute_loss(theta1, compute_feature1(data1_point), data1_label))
    # print(compute_accuracy(theta1, compute_feature1(data1_point), data1_label))
    theta1      = theta1 - data1_learning_rate * compute_gradient(theta1, compute_feature1(data1_point), data1_label)
    loss1       = compute_loss(theta1, compute_feature1(data1_point), data1_label)
    accuracy1   = compute_accuracy(theta1, compute_feature1(data1_point), data1_label)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    data1_loss_iteration[i]     = loss1
    data1_accuracy_iteration[i] = accuracy1

data1_theta_optimal = theta1

# %%
for i in range(data2_number_iteration):
    
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    theta2      = theta2 - data2_learning_rate * compute_gradient(theta2, compute_feature2(data2_point), data2_label)
    loss2       = compute_loss(theta2, compute_feature2(data2_point), data2_label)
    accuracy2   = compute_accuracy(theta2, compute_feature2(data2_point), data2_label)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    data2_loss_iteration[i]     = loss2
    data2_accuracy_iteration[i] = accuracy2

data2_theta_optimal = theta2
# Out:
# C:\Users\alsgu\AppData\Local\Temp\ipykernel_21824\463619455.py:8: RuntimeWarning: divide by zero encountered in log
#   + (1 - label) * (-np.log(1 - compute_logistic_regression(theta, feature)))
# C:\Users\alsgu\AppData\Local\Temp\ipykernel_21824\463619455.py:8: RuntimeWarning: invalid value encountered in multiply
#   + (1 - label) * (-np.log(1 - compute_logistic_regression(theta, feature)))

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
def function_result_01():

    print("final loss for data1 = {:13.10f}".format(data1_loss_iteration[-1]))

# %%
def function_result_02():

    print("final loss for data2 = {:13.10f}".format(data2_loss_iteration[-1]))

# %%
def function_result_03():

    print("final accuracy for data1 = {:13.10f}".format(data1_accuracy_iteration[-1]))

# %%
def function_result_04():

    print("final accuracy for data2 = {:13.10f}".format(data2_accuracy_iteration[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6))
    plt.title('loss for data1')

    plt.plot(data1_loss_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_06():

    plt.figure(figsize=(8,6))
    plt.title('loss for data2')

    plt.plot(data2_loss_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')

    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('accuracy for data1')

    plt.plot(data1_accuracy_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('accuracy for data2')

    plt.plot(data2_accuracy_iteration, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('accuracy')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the linear regression values over the 2-dimensional Euclidean space and superimpose the training data

# %%
def function_result_09():

    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('linear regression values')
    
    min_x   = np.min(data1_point_x)
    max_x   = np.max(data1_point_x)
    min_y   = np.min(data1_point_y)
    max_y   = np.max(data1_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(data1_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data1_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
    ZZ = data1_theta_optimal[0] + data1_theta_optimal[1] * XX + data1_theta_optimal[2] * (YY**2) + data1_theta_optimal[3] * (XX**2) + \
        data1_theta_optimal[4] * (XX + YY)
    plt.contour(X, Y, ZZ, levels = 0, colors = "black")
    plt.contourf(X, Y, ZZ, levels = np.linspace(np.min(ZZ), np.max(ZZ), 50, endpoint = False), cmap = "RdBu_r")
    plt.colorbar()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_10():
    
    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('linear regression values')
    
    min_x   = np.min(data2_point_x)
    max_x   = np.max(data2_point_x)
    min_y   = np.min(data2_point_y)
    max_y   = np.max(data2_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
    ZZ = data2_theta_optimal[0] + data2_theta_optimal[1] * XX + data2_theta_optimal[2] * (XX**2) + data2_theta_optimal[3] * (XX**3) + \
        data2_theta_optimal[4] * (XX**4) + data2_theta_optimal[5] * YY + data2_theta_optimal[6] * (YY**2)
    plt.contour(X, Y, ZZ, levels = 0, colors = "black")
    plt.contourf(X, Y, ZZ, levels = np.linspace(np.min(ZZ), np.max(ZZ), 50, endpoint = False), cmap = "RdBu_r")
    plt.colorbar()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## plot the logistic regression values over the 2-dimensional Euclidean space

# %%
def function_result_11():

    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('logistic regression values')
    
    min_x   = np.min(data1_point_x)
    max_x   = np.max(data1_point_x)
    min_y   = np.min(data1_point_y)
    max_y   = np.max(data1_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(data2_point_x_class_0, data2_point_y_class_0, 'o', color='blue', label='class = 0')
    plt.plot(data2_point_x_class_1, data2_point_y_class_1, 'o', color='red', label='class = 1')
    ZZ = data2_theta_optimal[0] + data2_theta_optimal[1] * XX + data2_theta_optimal[2] * (XX**2) + data2_theta_optimal[3] * (XX**3) + \
        data2_theta_optimal[4] * (XX**4) + data2_theta_optimal[5] * YY + data2_theta_optimal[6] * (YY**2)
    plt.contour(X, Y, ZZ, levels = 0, colors = "black")
    plt.contourf(X, Y, ZZ, levels = np.linspace(np.min(ZZ), np.max(ZZ), 50, endpoint = False), cmap = "RdBu_r")

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def function_result_12():
    
    plt.figure(figsize=(8,8)) # USE THIS VALUE for the size of the figure
    plt.title('logistic regression values')

    min_x   = np.min(data2_point_x)
    max_x   = np.max(data2_point_x)
    min_y   = np.min(data2_point_y)
    max_y   = np.max(data2_point_y)

    X = np.arange(min_x - 0.5, max_x + 0.5, 0.1) # USE THIS VALUE for the range of x values in the construction of coordinate
    Y = np.arange(min_y - 0.5, max_y + 0.5, 0.1) # USE THIS VALUE for the range of y values in the construction of coordinate

    [XX, YY] = np.meshgrid(X, Y)

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #



    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    plt.axis('equal')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ## results

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
number_result = 12

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss for data1 =  0.0114236732
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss for data2 =           nan
# **************************************************
# ## [RESULT 03]
# **************************************************
# final accuracy for data1 =  0.9990000000
# **************************************************
# ## [RESULT 04]
# **************************************************
# final accuracy for data2 =  0.9940000000
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# **************************************************
# ## [RESULT 10]
# **************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alsgu\OneDrive - 중앙대학교\중앙대 3학년 1학기\머신러닝\2022machinelearning.github.io\assignment_09.ipynb Cell 62' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000061?line=7'>8</a> print(title)
#       <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000061?line=8'>9</a> print('**************************************************')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000061?line=9'>10</a> eval(name_function)
#
# File <string>:1, in <module>
#
# c:\Users\alsgu\OneDrive - 중앙대학교\중앙대 3학년 1학기\머신러닝\2022machinelearning.github.io\assignment_09.ipynb Cell 53' in function_result_10()
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=13'>14</a> [XX, YY] = np.meshgrid(X, Y)
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=15'>16</a> # ++++++++++++++++++++++++++++++++++++++++++++++++++
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=16'>17</a> # complete the blanks
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=17'>18</a> #
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=18'>19</a> plt.plot(data12_point_x_class_0, data1_point_y_class_0, 'o', color='blue', label='class = 0')
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=19'>20</a> plt.plot(data2_point_x_class_1, data1_point_y_class_1, 'o', color='red', label='class = 1')
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=20'>21</a> ZZ = data2_theta_optimal[0] + data2_theta_optimal[1] * XX + data2_theta_optimal[2] * (XX**2) + data2_theta_optimal[3] * (XX**3) + \
#      <a href='vscode-notebook-cell:/c%3A/Users/alsgu/OneDrive%20-%20%EC%A4%91%EC%95%99%EB%8C%80%ED%95%99%EA%B5%90/%EC%A4%91%EC%95%99%EB%8C%80%203%ED%95%99%EB%85%84%201%ED%95%99%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/2022machinelearning.github.io/assignment_09.ipynb#ch0000052?line=21'>22</a>     data2_theta_optimal[4] * (XX**4) + data2_theta_optimal[5] * YY + data2_theta_optimal[6] * (YY**2)
#
# NameError: name 'data12_point_x_class_0' is not defined
